# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('bollywood1to950.csv')

# %%
df

# %%
df.info()

# %%
df.drop('Year',axis=1,inplace=True)

# %%
df.head()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms=MinMaxScaler()
features=ms.fit_transform(df.drop('Name',axis=1))

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(features)

# %%
cosine_df=pd.DataFrame(similarity,index=df['Name'],columns=df['Name'])

# %%
def recommend_movies(movie_name):
    print('Watched Movie:',movie_name)
    print('Recommended movies')
    for i in (cosine_df[movie_name].sort_values(ascending=False)[1:].head(10).index):
        print(i)

# %%
import random
random.choice(df['Name'])
# Out:
# 'Sadak 2'

# %%
recommend_movies('Dabangg 3')
# Out:
# Watched Movie: Dabangg 3
# Recommended movies
# Khaali Peeli
# Kalank
# Student of the Year 2
# Veere Di Wedding
# PM Narendra Modi
# Baaghi 3
# Housefull 4
# Love Will Take Over
# Pagalpanti
# Gul Makai
